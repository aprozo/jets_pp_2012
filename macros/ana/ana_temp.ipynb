# %%
# import ROOT
# ROOT.gStyle.SetOptStat(0)
# ROOT.ROOT.EnableImplicitMT(1)

# myRed =   ROOT.TColor(2000, (255. / 255.), (89. / 255.), (74. / 255.))
# myGreen = ROOT.TColor(2001, (25. / 255.), (170. / 255.), (25. / 255.))
# myBlue = ROOT.TColor(2002, (66. / 255.), (98. / 255.), (255. / 255.))
# myMagenta = ROOT.TColor(2003, (153. / 255.), (0. / 255.), (153. / 255.))
# myYellow = ROOT.TColor(2004, (255. / 255.), (166. / 255.), (33. / 255.))
# myAzure = ROOT.TColor(2005, (0. / 255.), (170. / 255.), (255. / 255.))
# myViolet = ROOT.TColor(2006, (204. / 255.), (153. / 255.), (255. / 255.))
# myOlive = ROOT.TColor(2007, (107. / 255.), (142. / 255.), (35. / 255.))
# myCornFlowerBlue = ROOT.TColor(2008, (100. / 255.), (149. / 255.),(237. / 255.))
# myOrangeRed = ROOT.TColor(2009, (255. / 255.), (69. / 255.), (0. / 255.))
# myTeal = ROOT.TColor(2010, (0. / 255.), (128. / 255.), (128. / 255.))
# myLightSteelBlue = ROOT.TColor(2011, (176. / 255.), (196. / 255.),(222. / 255.))
# myGold = ROOT.TColor(2012, (255. / 255.), (215. / 255.), (0. / 255.))

# %% [markdown]
# ## Load all prescales info first

# %%
import pandas as pd
lumi_MB_JP2 =  pd.read_csv("lumi_VPDMB_JP2.csv", index_col="run")
lumi_MB_HT2 =  pd.read_csv("lumi_VPDMB_BHT2.csv",index_col="run")
# keep only JP2 columns 'sampled_lumi_JP2', 'prescale_JP2', 'livetime_JP2', 'nevents_JP2', 
lumi_JP2=lumi_MB_JP2[['sampled_lumi_JP2', 'prescale_JP2', 'livetime_JP2', 'nevents_JP2']]
# add lumi_JP2 to lumi_MB_HT2
lumi=lumi_MB_HT2.join(lumi_JP2)
# show na values
# bad runs for BHT2  - 13052057 ,  13052059
# unique run for BHT2 only - 13054047 (JP2 was absent)
# drop na
lumi.dropna(inplace=True)
# drop HT2_weight
lumi.drop(columns=['HT2_weight'], inplace=True)
    #  'sampled_lumi_MB', 'prescale_MB', 'livetime_MB', 'nevents_MB',
    #  'sampled_lumi_HT2', 'prescale_HT2', 'livetime_HT2', 'nevents_HT2',
    #  'sampled_lumi_JP2', 'prescale_JP2', 'livetime_JP2', 'nevents_JP2'
# calculate ratios for JP2 and HT2 to MB
triggers = ['JP2', 'HT2']
for trigger in triggers:
    lumi[f'prescale_MB_over_{trigger}'] = lumi[f'prescale_MB'] / lumi[f'prescale_{trigger}']
    lumi[f'livetime_{trigger}_over_MB'] = lumi[f'livetime_{trigger}'] / lumi[f'livetime_MB']
    lumi[f'nevents_MB_over_{trigger}'] = lumi[f'nevents_MB'] / lumi[f'nevents_{trigger}']

# %%
# create a translatein map that enumerates runs
run_map = {run: i for i, run in enumerate(lumi.index.tolist())}
# creat inverse map
run_map_inv = {i: run for i, run in enumerate(lumi.index.tolist())}
# nicely print the run_map line by line
for key, value in run_map.items():
    print(f'{key}: {value}')
    # change index to the new one
# lumi['runid'] = lumi.index
# lumi.rename(index=run_map, inplace=True)
# Out:
# 13048009: 0
# 13048010: 1
# path='/home/prozorov/dev/star/jets_pp_2012/output/'
# triggers = ['HT2']
# tree_name = 'ResultTree'  # Update this to your tree name
# branch_names = ['runid1', 'pt', 'trigger_match_jp', 'trigger_match_ht']

# trigger = 'HT2'
# root_file_path = path + f'jets_{trigger}.root'
# root_file = uproot.open(root_file_path)
# tree = root_file[tree_name]
# tree_arrays=tree.arrays(branch_names, library='pd')

# %% [markdown]
# ## Analyze the data MB, JP2, HT2

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
import pandas as pd
path='/home/prozorov/dev/star/jets_pp_2012/output/'
triggers = ['HT2', 'JP2','MB']
tree_name = 'ResultTree'  # Update this to your tree name
branch_names = ['runid1', 'pt', 'trigger_match_jp', 'trigger_match_ht']

data={}

def get_event_hist(root_file):
    histogram = root_file["hEventsRun"] # read events per run histogram with x-labels as run ids
    runids = histogram.axis().labels()
    runids = [int(runid) for runid in runids]
    events = histogram.values()
    analyzed_events_map = {runid: event for runid, event in zip(runids, events)}
    return analyzed_events_map

for trigger in triggers:
    root_file_path = path + f'jets_{trigger}.root'
    root_file = uproot.open(root_file_path)
    tree = root_file[tree_name]
    tree_arrays = tree.arrays(branch_names, library="np")
    
    # rename colum runid1 to run
    tree_arrays['run'] = tree_arrays['runid1']
    tree_arrays.pop('runid1')
    # rename trigger_match_jp to trigger_match
    if trigger=='JP2':
        tree_arrays['trigger_match'] = tree_arrays['trigger_match_jp']
    else:
        tree_arrays['trigger_match'] = tree_arrays['trigger_match_ht']

    tree_arrays.pop('trigger_match_jp')
    tree_arrays.pop('trigger_match_ht')

    analyzed_events_map= get_event_hist(root_file)
    # merge data with analyzed_events
    tree_arrays['analyzed_events'] = [analyzed_events_map[run] for run in tree_arrays['run']]
    data.update({trigger: tree_arrays})

# %%
# create a list of common runs for JP2 and MB based on root_file["hEventsRun"] if values in the run > 0
def get_df_from_eventhist(path):
    root_file = uproot.open(path)
    histogram = root_file["hEventsRun"]
    runids = histogram.axis().labels()
    runids = [int(runid) for runid in runids]
    events = histogram.values()
    df = pd.DataFrame({'run': runids, 'analyzed_events': events})
    df = df[df['analyzed_events'] > 0]
    return df

df_eventhist_MB = get_df_from_eventhist(path + 'jets_MB.root')
df_eventhist_JP2 = get_df_from_eventhist(path + 'jets_JP2.root')
df_eventhist_HT2 = get_df_from_eventhist(path + 'jets_HT2.root')

temp_JP2=df_eventhist_JP2.merge(df_eventhist_MB, on='run', how='inner')
common_runs_JP2_MB = temp_JP2['run'].tolist()

temp_HT2=df_eventhist_HT2.merge(df_eventhist_MB, on='run', how='inner')
common_runs_HT2_MB = temp_HT2['run'].tolist()

bad_runs=[13048019,
 13048092,
 13048093,
 13049006,
 13049007,
 13051074,
 13051099,
 13052061,
 13061035,
 13064067,
 13068060,
 13069023,
 13070061]

# remove bad runs
common_runs_JP2_MB = [run for run in common_runs_JP2_MB if run not in bad_runs]
common_runs_HT2_MB = [run for run in common_runs_HT2_MB if run not in bad_runs]



common_runs={ 'JP2': common_runs_JP2_MB, 'HT2': common_runs_HT2_MB}

# %%
common_runs['JP2']
# Out:
# [13048009,
#  13048010,
#  13048011,
#  13048012,
#  13048013,
#  13048014,
#  13048015,
#  13048016,
#  13048017,
#  13048018,
#  13048030,
#  13048031,
#  13048032,
#  13048040,
#  13048041,
#  13048042,
#  13048043,
#  13048044,
#  13048045,
#  13048049,
#  13048050,
#  13048051,
#  13048052,
#  13048053,
#  13048087,
#  13048088,
#  13048089,
#  13048090,
#  13048091,
#  13049031,
#  13049032,
#  13049035,
#  13049039,
#  13049041,
#  13049042,
#  13049044,
#  13049045,
#  13049046,
#  13049047,
#  13049048,
#  13049049,
#  13049072,
#  13049073,
#  13049080,
#  13049081,
#  13049082,
#  13049093,
#  13049094,
#  13049096,
#  13049098,
#  13049099,
#  13049101,
#  13050001,
#  13050006,
#  13050009,
#  13050011,
#  13050012,
#  13050015,
#  13050016,
#  13050020,
#  13050022,
#  13050023,
#  13050028,
#  13050029,
#  13050031,
#  13050032,
#  13050036,
#  13050037,
#  13050038,
#  13050041,
#  13051006,
#  13051007,
#  13051008,
#  13051009,
#  13051010,
#  13051011,
#  13051012,
#  13051015,
#  13051016,
#  13051017,
#  13051019,
#  13051020,
#  13051021,
#  13051022,
#  13051023,
#  13051024,
#  13051026,
#  13051028,
#  13051069,
#  13051070,
#  13051071,
#  13051072,
#  13051073,
#  13051081,
#  13051083,
#  13051085,
#  13051086,
#  13051087,
#  13051091,
#  13051092,
#  13051093,
#  13051100,
#  13052001,
#  13052002,
#  13052003,
#  13052004,
#  13052005,
#  13052009,
#  13052010,
#  13052011,
#  13052012,
#  13052013,
#  13052014,
#  13052015,
#  13052016,
#  13052017,
#  13052018,
#  13052019,
#  13052020,
#  13052036,
#  13052037,
#  13052039,
#  13052042,
#  13052043,
#  13052045,
#  13052048,
#  13052050,
#  13052051,
#  13052052,
#  13052053,
#  13052056,
#  13052088,
#  13053004,
#  13053005,
#  13053006,
#  13053007,
#  13053012,
#  13053013,
#  13053015,
#  13053023,
#  13053027,
#  13053028,
#  13053029,
#  13054010,
#  13054023,
#  13054043,
#  13054044,
#  13054058,
#  13054060,
#  13054061,
#  13054062,
#  13054063,
#  13054064,
#  13054065,
#  13054066,
#  13054068,
#  13054069,
#  13054070,
#  13054084,
#  13054085,
#  13055001,
#  13055004,
#  13055006,
#  13055007,
#  13055008,
#  13055009,
#  13055010,
#  13055011,
#  13055014,
#  13055016,
#  13055017,
#  13055018,
#  13055019,
#  13055020,
#  13055021,
#  13055022,
#  13055023,
#  13055024,
#  13055034,
#  13055035,
#  13055036,
#  13055037,
#  13055038,
#  13055039,
#  13055068,
#  13055069,
#  13055070,
#  13055071,
#  13055073,
#  13055075,
#  13055076,
#  13055080,
#  13056004,
#  13056005,
#  13056007,
#  13056008,
#  13056017,
#  13056020,
#  13056021,
#  13056022,
#  13056023,
#  13056024,
#  13056025,
#  13056026,
#  13056027,
#  13056028,
#  13056029,
#  13056030,
#  13056031,
#  13056033,
#  13057005,
#  13057006,
#  13057007,
#  13057008,
#  13057009,
#  13057010,
#  13057011,
#  13057014,
#  13057015,
#  13057016,
#  13057017,
#  13057018,
#  13057019,
#  13057021,
#  13057022,
#  13057023,
#  13057024,
#  13057025,
#  13057026,
#  13057027,
#  13057042,
#  13057044,
#  13057045,
#  13057046,
#  13057047,
#  13057048,
#  13057049,
#  13057050,
#  13057051,
#  13057052,
#  13057053,
#  13057055,
#  13057056,
#  13057057,
#  13057058,
#  13058002,
#  13058003,
#  13058008,
#  13058013,
#  13058014,
#  13058015,
#  13058016,
#  13058017,
#  13058018,
#  13058020,
#  13058023,
#  13058025,
#  13058026,
#  13058028,
#  13058029,
#  13058031,
#  13058032,
#  13060007,
#  13060008,
#  13060010,
#  13060011,
#  13061024,
#  13061025,
#  13061029,
#  13061030,
#  13061031,
#  13061053,
#  13061054,
#  13061055,
#  13061056,
#  13061059,
#  13061060,
#  13061061,
#  13062001,
#  13062002,
#  13062004,
#  13062005,
#  13062006,
#  13062007,
#  13062013,
#  13062025,
#  13062026,
#  13062028,
#  13062029,
#  13062045,
#  13062049,
#  13062050,
#  13062052,
#  13062059,
#  13062060,
#  13062061,
#  13062062,
#  13062063,
#  13063009,
#  13063010,
#  13063011,
#  13063020,
#  13063022,
#  13063023,
#  13063030,
#  13063031,
#  13063032,
#  13063034,
#  13063035,
#  13063036,
#  13063051,
#  13063053,
#  13063054,
#  13063062,
#  13063063,
#  13063065,
#  13063067,
#  13063068,
#  13063071,
#  13063072,
#  13063073,
#  13063074,
#  13063076,
#  13064001,
#  13064002,
#  13064003,
#  13064004,
#  13064005,
#  13064006,
#  13064012,
#  13064014,
#  13064020,
#  13064021,
#  13064022,
#  13064023,
#  13064024,
#  13064025,
#  13064026,
#  13064028,
#  13064029,
#  13064031,
#  13064032,
#  13064052,
#  13064055,
#  13064056,
#  13064061,
#  13064064,
#  13064065,
#  13064066,
#  13064068,
#  13064070,
#  13064075,
#  13065005,
#  13065006,
#  13065007,
#  13065008,
#  13065009,
#  13065013,
#  13065014,
#  13065015,
#  13065016,
#  13065017,
#  13065018,
#  13065019,
#  13065020,
#  13065021,
#  13065022,
#  13065046,
#  13065047,
#  13065049,
#  13065050,
#  13065051,
#  13065052,
#  13065053,
#  13065055,
#  13065056,
#  13065058,
#  13065059,
#  13065060,
#  13066021,
#  13066022,
#  13066023,
#  13066024,
#  13066025,
#  13066026,
#  13066027,
#  13066028,
#  13066029,
#  13066030,
#  13066031,
#  13066033,
#  13066034,
#  13068057,
#  13068058,
#  13068059,
#  13068084,
#  13068085,
#  13068086,
#  13068087,
#  13068088,
#  13068090,
#  13069001,
#  13069002,
#  13069003,
#  13069004,
#  13069005,
#  13069007,
#  13069008,
#  13069013,
#  13069014,
#  13069016,
#  13069017,
#  13069018,
#  13069020,
#  13069021,
#  13069022,
#  13069024,
#  13069026,
#  13069027,
#  13069030,
#  13069031,
#  13069035,
#  13069036,
#  13069066,
#  13069067,
#  13069068,
#  13069069,
#  13069073,
#  13070006,
#  13070008,
#  13070010,
#  13070011,
#  13070012,
#  13070014,
#  13070015,
#  13070016,
#  13070017,
#  13070018,
#  13070019,
#  13070020,
#  13070021,
#  13070022,
#  13070024,
#  13070025,
#  13070026,
#  13070027,
#  13070057,
#  13070058,
#  13070059,
#  13070060,
#  13071003,
#  13071004,
#  13071005,
#  13071006,
#  13071008,
#  13071009,
#  13071010,
#  13071011,
#  13071012,
#  13071028,
#  13071029,
#  13071031,
#  13071032,
#  13071033,
#  13071041,
#  13071042,
#  13071043,
#  13071045,
#  13071046,
#  13071048,
#  13071050,
#  13071051,
#  13071055,
#  13071064,
#  13072001,
#  13072002,
#  13072003,
#  13072004,
#  13072005,
#  13072006,
#  13072007,
#  13072008,
#  13072009,
#  13072010,
#  13072011,
#  13072014,
#  13072015,
#  13072016,
#  13072017,
#  13072018,
#  13072019,
#  13072020]

# %%
def process_trigger_data(trigger_data, lumi, trigger):
    """
    -----------
    data : DataFrame
        Data dictionary containing trigger-specific DataFrames
    lumi : DataFrame
        DataFrame containing luminosity information
    trigger : str
        Trigger name (e.g., 'HT2', 'JP2')
    Returns:
    --------
    DataFrame
        Processed trigger data with all weights calculated
    """
    # Calculate basic weight
    trigger_data['weight'] = 1 / trigger_data['analyzed_events']
    # For HT2 and JP2 triggers, apply additional corrections
    if trigger in ['JP2', 'HT2']:
        # Define columns to merge
        columns_to_merge = [
            f'livetime_{trigger}_over_MB', 
            f'prescale_MB_over_{trigger}', 
            f'nevents_MB_over_{trigger}'
        ]        
        # Merge lumi information with trigger data
        trigger_data = pd.merge(
            trigger_data,
            lumi[columns_to_merge],
            on='run',
            how='left'
        )
        # Calculate weights sequentially, using method chaining for readability
        trigger_data = (trigger_data.assign(
                                        weight_livetime=lambda df: df['weight'] / df[f'livetime_{trigger}_over_MB'],                                    
                                        weight_livetime_prescale=lambda df: df['weight_livetime'] / df[f'prescale_MB_over_{trigger}'],
                                        weight_livetime_prescale_nevents=lambda df: df['weight_livetime_prescale'] / df[f'nevents_MB_over_{trigger}'],
                                        fully_corrected=lambda df: df['weight_livetime_prescale_nevents'] * df['trigger_match'] 
                                        )
                )
    else:
        trigger_data['fully_corrected'] = trigger_data['weight']
    
    return trigger_data
   

for trigger in triggers:
    pt_values            = np.concatenate([arr for arr in data[trigger]['pt'] if arr.size > 0])
    trigger_match_values = np.concatenate([arr for arr in data[trigger]['trigger_match'] if arr.size > 0]) 
    trigger_match_values = trigger_match_values.astype(int)
    run_values           = np.concatenate([[run] * len(arr) for run, arr in zip(data[trigger]['run'], data[trigger]['pt']) if arr.size > 0])
    analyzed_events_values = np.concatenate([[ana] * len(arr) for ana, arr in zip(data[trigger]['analyzed_events'], data[trigger]['pt']) if arr.size > 0])

    trigger_data = pd.DataFrame({'run': run_values, 'pt': pt_values, 'trigger_match': trigger_match_values, 'analyzed_events': analyzed_events_values})

    trigger_data['run_mapped'] = trigger_data['run'].map(run_map)
    trigger_data = process_trigger_data(trigger_data, lumi, trigger)
    data[trigger] = trigger_data

# %%
import ROOT
# %jsroot on

# %%
trigger = 'JP2'
# set corretct common run list for further analysis
common_runs_list = common_runs[trigger]
# filter data for MB and for trigger based on comm
data[trigger]=data[trigger][data[trigger]['run'].isin(common_runs_list)]
data['MB']=data['MB'][data['MB']['run'].isin(common_runs_list)]

trigger_df={}
trigger_df.update({trigger: ROOT.RDF.FromPandas(data[trigger])})
trigger_df.update({'MB': ROOT.RDF.FromPandas(data['MB'])})

# %%
df = trigger_df[trigger]
title = '; run ;p_{t}, GeV/c; counts per event'
nbins_pt = 20
h_norm_lt_ps_maxevt_trigger  =df.Histo2D (('h_norm_lt_ps_maxevt_trigger',   f'{trigger}+livetime+prescale+maxevents+trigger'+title, len(run_map), 0, len(run_map), nbins_pt, 5, 40), 'run_mapped', 'pt', 'fully_corrected')
# convert labels to run ids
for i in range(len(run_map)):
    h_norm_lt_ps_maxevt_trigger.GetXaxis().SetBinLabel(i+1, str(run_map_inv[i]))  

can = ROOT.TCanvas('can', 'can', 800, 600)
can.Draw()
h_norm_lt_ps_maxevt_trigger.Draw('colz')
# Out:
# <div id="root_plot_1742692576447" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1742692576447(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":0,"fXtoPixelk":0,"fXtoPixel":796,"fYtoAbsPixelk":572,"fYtoPixelk":572,"fYtoPixel":-572,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":0.00125628140703518,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00174825174825175,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":true,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"can","fTitle":"can","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":15,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:201,31,22;112:200,73,169;113:173,173,125;114:134,200,221;115:87,141,255;116:101,99,100;117:63,144,218;118:255,169,14;119:189,31,1;120:148,164,162;121:131,45,182;122:169,107,89;123:231,99,0;124:185,172,112;125:113,117,129;126:146,218,221;127:178, ...

# %%
title = '; run ;p_{t}, GeV/c; counts per event'
nbins_pt = 20

df = trigger_df[trigger]

h_raw=df.Histo2D (('raw_pt_run', f'{trigger}'+ ' raw; run ;p_{t}, GeV/c; counts', len(run_map), 0, len(run_map), nbins_pt, 5, 40), 'run_mapped', 'pt')
h_norm                       =df.Histo2D (('h_norm',                        f'{trigger}'+title,len(run_map), 0, len(run_map), nbins_pt, 5, 40), 'run_mapped', 'pt', 'weight')
h_norm_lt                    =df.Histo2D (('h_norm_lt',                     f'{trigger}+livetime'+title,len(run_map), 0, len(run_map), nbins_pt, 5, 40), 'run_mapped', 'pt', 'weight_livetime')
h_norm_lt_ps                 =df.Histo2D (('h_norm_lt_ps',                  f'{trigger}+livetime+prescale'+title,len(run_map), 0, len(run_map), nbins_pt, 5, 40), 'run_mapped', 'pt', 'weight_livetime_prescale')
h_norm_lt_ps_maxevt          =df.Histo2D (('h_norm_lt_ps_maxevt',           f'{trigger}+livetime+prescale+maxevents'+title,len(run_map), 0, len(run_map), nbins_pt, 5, 40), 'run_mapped', 'pt', 'weight_livetime_prescale_nevents')
h_norm_lt_ps_maxevt_trigger  =df.Histo2D (('h_norm_lt_ps_maxevt_trigger',   f'{trigger}+livetime+prescale+maxevents+trigger'+title,len(run_map), 0, len(run_map), nbins_pt, 5, 40), 'run_mapped', 'pt', 'fully_corrected')

# convert labels to run ids
for i in range(len(run_map)):
    h_raw.GetXaxis().SetBinLabel(i+1, str(run_map_inv[i]))
    h_norm.GetXaxis().SetBinLabel(i+1, str(run_map_inv[i]))
    h_norm_lt.GetXaxis().SetBinLabel(i+1, str(run_map_inv[i]))
    h_norm_lt_ps.GetXaxis().SetBinLabel(i+1, str(run_map_inv[i]))
    h_norm_lt_ps_maxevt.GetXaxis().SetBinLabel(i+1, str(run_map_inv[i]))
    h_norm_lt_ps_maxevt_trigger.GetXaxis().SetBinLabel(i+1, str(run_map_inv[i]))

# %%
def set_pallette(h2):
    palette = h2.GetListOfFunctions().FindObject("palette")
    # h2.GetXaxis().SetTitleOffset(1.5)
    # h2.GetZaxis().SetTitleOffset(1.3)
    if palette:
        palette.SetX1NDC(0.88)  # Left boundary (NDC coordinates)
        palette.SetX2NDC(0.9)  # Right boundary (makes it thinner)
    ROOT.gPad.SetLogz()
    ROOT.gPad.Update()

can = ROOT.TCanvas('can2', 'can', 1600, 800)
# set common z axis log scale
can.Clear()
can.Divide(3,2)

can.cd(1) 
h_raw.Draw("colz")
set_pallette(h_raw)

can.cd(2)
h_norm.Draw("colz")
set_pallette(h_norm)

can.cd(3)
h_norm_lt.Draw("colz")
set_pallette(h_norm_lt)

can.cd(4)
h_norm_lt_ps.Draw("colz")
set_pallette(h_norm_lt_ps)

can.cd(5)
h_norm_lt_ps_maxevt.Draw("colz")
set_pallette(h_norm_lt_ps_maxevt)

can.cd(6)
h_norm_lt_ps_maxevt_trigger.Draw("colz")
set_pallette(h_norm_lt_ps_maxevt_trigger)

can.Draw()
can.SaveAs(f'plots/goodruns_{trigger}.pdf')
# Out:
# Info in <TCanvas::Print>: pdf file plots/goodruns_JP2.pdf has been created
# <div id="root_plot_1742692582252" style="width: 1600px; height: 800px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1742692582252(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0,"fY1":0,"fX2":1,"fY2":1,"fXtoAbsPixelk":0,"fXtoPixelk":0,"fXtoPixel":1596,"fYtoAbsPixelk":772,"fYtoPixelk":772,"fYtoPixel":-772,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":1596,"fVtoAbsPixelk":772,"fVtoPixelk":772,"fVtoPixel":-772,"fAbsPixeltoXk":0,"fPixeltoXk":0,"fPixeltoX":6.265664160401e-4,"fAbsPixeltoYk":1,"fPixeltoYk":0,"fPixeltoY":-0.00129533678756477,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":0,"fUxmax":1,"fUymax":1,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"can2","fTitle":"can","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":10,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":1596,"fCh":772,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:201,31,22;112:200,73,169;113:173,173,125;114:134,200,221;115:87,141,255;116:101,99,100;117:63,144,218;118:255,169,14;119:189,31,1;120:148,164,162;121:131,45,182;122:169,107,89;123:231,99,0;124:185,172,112;125:113,117,129;126:146,218,221;127:1 ...

# %%
can1d = ROOT.TCanvas('can1d', 'can1d', 800, 600)

# %%
# compare 1D distributions
title = ';p_{t}, GeV/c; counts per event'
nbins_pt = 20

df = trigger_df[trigger]

mb_norm = trigger_df['MB'].Histo1D (('mb_norm', 'MB'+title, nbins_pt, 5, 40), 'pt', 'fully_corrected')

h1_raw                        =df.Histo1D (('raw',                         f'{trigger}'+ ' raw; p_{t}, GeV/c; counts',  nbins_pt, 5, 40), 'pt')
h1_norm                       =df.Histo1D (('norm',                        f'{trigger}'+title, nbins_pt, 5, 40), 'pt', 'weight')
h1_norm_lt                    =df.Histo1D (('norm_lt',                     f'{trigger}+livetime'+title, nbins_pt, 5, 40), 'pt', 'weight_livetime')
h1_norm_lt_ps                 =df.Histo1D (('norm_lt_ps',                  f'{trigger}+livetime+prescale'+title, nbins_pt, 5, 40), 'pt', 'weight_livetime_prescale')
h1_norm_lt_ps_maxevt          =df.Histo1D (('norm_lt_ps_maxevt',           f'{trigger}+livetime+prescale+maxevents'+title, nbins_pt, 5, 40), 'pt', 'weight_livetime_prescale_nevents')
h1_norm_lt_ps_maxevt_trigger  =df.Histo1D (('norm_lt_ps_maxevt_trigger',   f'{trigger}+livetime+prescale+maxevents+trigger'+title, nbins_pt, 5, 40), 'pt', 'fully_corrected')
can1d.Draw()
can1d.SetLogy()

h1_norm_lt_ps.SetMarkerColor(ROOT.kRed) 
h1_norm_lt_ps.SetLineColor(ROOT.kRed)
h1_norm_lt_ps.SetMarkerStyle (20)
h1_norm_lt_ps.SetMarkerSize(0.8)
h1_norm_lt.SetMarkerColor(ROOT.kMagenta)
h1_norm_lt.SetLineColor(ROOT.kMagenta)
h1_norm_lt.SetMarkerStyle (21)
h1_norm_lt.SetMarkerSize(0.8)
h1_norm_lt_ps_maxevt.SetMarkerColor(ROOT.kBlue-1)
h1_norm_lt_ps_maxevt.SetLineColor(ROOT.kBlue-1)
h1_norm_lt_ps_maxevt.SetMarkerStyle (22)
h1_norm_lt_ps_maxevt.SetMarkerSize(0.8)

h1_norm_lt_ps_maxevt_trigger.SetMarkerColor(ROOT.kOrange+1)
h1_norm_lt_ps_maxevt_trigger.SetLineColor(ROOT.kOrange+1)
h1_norm_lt_ps_maxevt_trigger.SetMarkerStyle (23)
h1_norm_lt_ps_maxevt_trigger.SetMarkerSize(0.8)

mb_norm.SetMarkerColor(ROOT.kAzure)
mb_norm.SetLineColor(ROOT.kAzure)
mb_norm.SetMarkerStyle (24)
mb_norm.SetMarkerSize(0.8)


   
h1_norm.GetYaxis().SetRangeUser(1e-6, 1e2)
h1_norm.Draw('pe')
h1_norm_lt.Draw('same pe')
h1_norm_lt_ps.Draw('same pe')
h1_norm_lt_ps_maxevt.Draw('same pe')
h1_norm_lt_ps_maxevt_trigger.Draw('same pe')
mb_norm.Draw('same pe')
can1d.BuildLegend()
can1d.Draw()

can1d.SaveAs(f'plots/{trigger}_1d.pdf')
# Out:
# Info in <TCanvas::Print>: pdf file plots/MB_1d.pdf has been created

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %jsroot on
ROOT.gStyle.SetOptStat(0)
can = ROOT.TCanvas('can', 'can', 800, 600)
can.Draw()
can.SetLogy()

def dataframe_to_TH1(df,column, hist_name="hist"):
    """
    Convert a Pandas DataFrame with into a ROOT TH1D histogram.
    Returns:
    - ROOT.TH1D histogram with custom bin labels.
    """
    rows = df.index.to_list()  # Extract run IDs
    entries = df[column].to_list()  # Extract event counts
    name = df.index.name  # Get the name of the index column

    n_bins = len(rows)
    hist = ROOT.TH1D(hist_name, hist_name, n_bins, 0, n_bins)  # Create histogram

    # Assign bin labels and fill histogram
    for i, run_id in enumerate(rows):
        bin_index = i + 1  # ROOT bins start from 1
        hist.GetXaxis().SetBinLabel(bin_index, str(run_id))  # Set custom labels
        hist.SetBinContent(bin_index, entries[i])  # Fill with event counts
    return hist

trigger='MB'
root_file_path = path + f'jets_{trigger}.root'
root_file = uproot.open( root_file_path )
analyzed_events_map = get_event_hist(root_file)
events_per_run =  pd.DataFrame.from_dict(analyzed_events_map, orient='index', columns=['events'])
current_events_per_run = dataframe_to_TH1(events_per_run, "events", "current_events_per_run")


for trigger in triggers:
    prescale_ratio = dataframe_to_TH1(lumi, f'prescale_MB_over_{trigger}', f'prescale_MB_over_{trigger}')
    livetime_ratio = dataframe_to_TH1(lumi, f'livetime_{trigger}_over_MB', f'livetime_{trigger}_over_MB')
    maxnevent_ratio = dataframe_to_TH1(lumi, f'nevents_MB_over_{trigger}', f'nevents_MB_over_{trigger}')

    prescale_ratio.SetMarkerColor(2000) 
    prescale_ratio.SetLineColor(2000)
    prescale_ratio.SetMarkerStyle (20)
    prescale_ratio.SetMarkerSize(0.8)
    livetime_ratio.SetMarkerColor(2001)
    livetime_ratio.SetLineColor(2001)
    livetime_ratio.SetMarkerStyle (21)
    livetime_ratio.SetMarkerSize(0.8)

    maxnevent_ratio.SetMarkerColor(2002)
    maxnevent_ratio.SetLineColor(2002)
    maxnevent_ratio.SetMarkerStyle (22)
    maxnevent_ratio.SetMarkerSize(0.8)
   
    leg = ROOT.TLegend(0.6, 0.7, 0.9, 0.9)
    leg.AddEntry(prescale_ratio, f'prescale MB/{trigger}', 'p')
    leg.AddEntry(livetime_ratio, f'livetime {trigger}/MB', 'p')
    leg.AddEntry(maxnevent_ratio, f'maxnevents MB/{trigger}', 'p')
    prescale_ratio.SetTitle(f'{trigger};runid; ratio')
    # set grid


    prescale_ratio.GetYaxis().SetRangeUser(0.2, 10000)
    prescale_ratio.Draw("pl")
    livetime_ratio.Draw("lp same")
    maxnevent_ratio.Draw("lp same ")
    leg.Draw()
    can.SaveAs(f'plots/{trigger}_prescales_ratio.pdf')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/dev/star/jets_pp_2012/macros/ana/.conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prescale_MB_over_MB'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 36
#      32 current_events_per_run = dataframe_to_TH1(events_per_run, "events", "current_events_per_run")
#      35 for trigger in triggers:
# ---> 36     prescale_ratio = dataframe_to_TH1(lumi, f'prescale_MB_over_{trigger}', f'prescale_MB_over_{trigger}')
#      37     livetime_ratio = dataframe_to_TH1(lumi, f'livetime_{trigger}_over_MB', f'livetime_{trigger}_over_MB')
#      38     maxnevent_ratio = dataframe_to_TH1(lumi, f'nevents_MB_over_{trigger}', f'nevents_MB_over_{trigger}')
#
# Cell In[21], line 14, in dataframe_to_TH1(df, column, hist_name)
#       8 """
#       9 Convert a Pandas DataFrame with into a ROOT TH1D histogram.
#      10 Returns:
#      11 - ROOT.TH1D histogram with custom bin labels.
#      12 """
#      13 rows = df.index.to_list()  # Extract run IDs
# ---> 14 entries = df[column].to_list()  # Extract event counts
#      15 name = df.index.name  # Get the name of the index column
#      17 n_bins = len(rows)
#
# File ~/dev/star/jets_pp_2012/macros/ana/.conda/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/dev/star/jets_pp_2012/macros/ana/.conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'prescale_MB_over_MB'
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: can
# Info in <TCanvas::Print>: pdf file plots/HT2_prescales_ratio.pdf has been created
# Info in <TCanvas::Print>: pdf file plots/JP2_prescales_ratio.pdf has been created
# <div id="root_plot_1742692588869" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1742692588869(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-66.0000049173835,"fY1":-1.28634129864059,"fX2":594.000004917384,"fY2":4.58737129430457,"fXtoAbsPixelk":79.6000047445299,"fXtoPixelk":79.6000047445299,"fXtoPixel":1.2060605880889,"fYtoAbsPixelk":446.73217131765,"fYtoPixelk":446.73217131765,"fYtoPixel":-97.383041977066,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-66.0000049173835,"fPixeltoXk":-66.0000049173835,"fPixeltoX":0.829145740998451,"fAbsPixeltoYk":4.58737129430457,"fPixeltoYk":-1.28634129864059,"fPixeltoY":-0.0102687283093447,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":0,"fUymin":-0.698970004336019,"fUxmax":528,"fUymax":4,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":1,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"can","fTitle":"can","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":15,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:201,31,22;112:200,73,169; ...
